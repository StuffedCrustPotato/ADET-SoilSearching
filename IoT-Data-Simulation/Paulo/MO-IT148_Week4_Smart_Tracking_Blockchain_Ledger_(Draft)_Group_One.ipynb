# %%
from web3 import Web3

# Connect to local Ganache blockchain
ganache_url = "http://127.0.0.1:7545" # <<-- IMPORTANT: Check this port against Ganache!
web3 = Web3(Web3.HTTPProvider(ganache_url))

if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running and the URL/port are correct.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from web3 import Web3
#       3 # Connect to local Ganache blockchain
#       4 ganache_url = "http://127.0.0.1:7545" # <<-- IMPORTANT: Check this port against Ganache!
#
# ModuleNotFoundError: No module named 'web3'

# %%
# !pip install web3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.5/587.5 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 12.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from web3 import Web3

# Connect to local Ganache blockchain
ganache_url = "http://127.0.0.1:7545" # <<-- IMPORTANT: Check this port against Ganache!
web3 = Web3(Web3.HTTPProvider(ganache_url))

if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running and the URL/port are correct.")
# Out:
# ✅ Connected to Ganache successfully!

# %%
# Replace with actual contract address from Remix
contract_address = "0x07999b0dCB2d0c7122e507532C11813e5e19b3fb" # <-- REPLACE THIS STRING


# Paste the ABI from Remix
abi_json_string = """
[
	{
		"inputs": [],
		"stateMutability": "nonpayable",
		"type": "constructor"
	},
	{
		"anonymous": false,
		"inputs": [
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "blockTimestamp",
				"type": "uint256"
			},
			{
				"indexed": false,
				"internalType": "string",
				"name": "sensorId",
				"type": "string"
			},
			{
				"indexed": false,
				"internalType": "int256",
				"name": "temperatureC_scaled",
				"type": "int256"
			},
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "humidityPercent",
				"type": "uint256"
			},
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "co2PPM",
				"type": "uint256"
			},
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "pm25ugm3_scaled",
				"type": "uint256"
			},
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "soilMoisturePercent",
				"type": "uint256"
			},
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "pH_scaled",
				"type": "uint256"
			},
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "turbidityNTU_scaled",
				"type": "uint256"
			},
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "contaminationPPM_scaled",
				"type": "uint256"
			}
		],
		"name": "EnvironmentalDataStored",
		"type": "event"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "_sensorId",
				"type": "string"
			},
			{
				"internalType": "int256",
				"name": "_temperatureC_scaled",
				"type": "int256"
			},
			{
				"internalType": "uint256",
				"name": "_humidityPercent",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_co2PPM",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_pm25ugm3_scaled",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_soilMoisturePercent",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_pH_scaled",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_turbidityNTU_scaled",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_contaminationPPM_scaled",
				"type": "uint256"
			}
		],
		"name": "storeEnvironmentalData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"name": "dataRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "blockTimestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "sensorId",
				"type": "string"
			},
			{
				"internalType": "int256",
				"name": "temperatureC_scaled",
				"type": "int256"
			},
			{
				"internalType": "uint256",
				"name": "humidityPercent",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "co2PPM",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "pm25ugm3_scaled",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "soilMoisturePercent",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "pH_scaled",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "turbidityNTU_scaled",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "contaminationPPM_scaled",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "index",
				"type": "uint256"
			}
		],
		"name": "getRecord",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "blockTimestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "sensorId",
				"type": "string"
			},
			{
				"internalType": "int256",
				"name": "temperatureC_scaled",
				"type": "int256"
			},
			{
				"internalType": "uint256",
				"name": "humidityPercent",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "co2PPM",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "pm25ugm3_scaled",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "soilMoisturePercent",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "pH_scaled",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "turbidityNTU_scaled",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "contaminationPPM_scaled",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getTotalRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "MAX_ENTRIES",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "owner",
		"outputs": [
			{
				"internalType": "address",
				"name": "",
				"type": "address"
			}
		],
		"stateMutability": "view",
		"type": "function"
	}
]
"""
# Parse the JSON string into a Python list/dictionary
abi = json.loads(abi_json_string)

# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)


# Set the default sender address (first account from Ganache)
# This account will be used for sending transactions if no 'from' address is specified
web3.eth.default_account = web3.eth.accounts[0]


print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0x07999b0dCB2d0c7122e507532C11813e5e19b3fb

# %%
# Call getTotalRecords() to check if the contract is responding.
total_records = contract.functions.getTotalRecords().call()
print(f"Total Records: {total_records}")
# Out:
# Total Records: 0

# %%
# Store a dummy IoT data entry manually to test if transactions work:

# Prepare dummy data matching your contract's storeEnvironmentalData function
# Remember the scaled integer types:
# temperatureC_scaled (int256, original * 10)
# humidityPercent (uint256)
# co2PPM (uint256)
# pm25ugm3_scaled (uint256, original * 10)
# soilMoisturePercent (uint256)
# pH_scaled (uint256, original * 10)
# turbidityNTU_scaled (uint256, original * 10)
# contaminationPPM_scaled (uint256, original * 100)

dummy_sensor_id = "TEST-SENSOR-001"
dummy_temperature = int(25.5 * 10) # 25.5 C scaled to 255
dummy_humidity = 60
dummy_co2 = 800
dummy_pm25 = int(12.3 * 10) # 12.3 ug/m3 scaled to 123
dummy_soil_moisture = 45
dummy_ph = int(7.0 * 10) # 7.0 pH scaled to 70
dummy_turbidity = int(5.1 * 10) # 5.1 NTU scaled to 51
dummy_contamination = int(0.75 * 100) # 0.75 ppm scaled to 75


txn = contract.functions.storeEnvironmentalData(
    dummy_sensor_id,
    dummy_temperature,
    dummy_humidity,
    dummy_co2,
    dummy_pm25,
    dummy_soil_moisture,
    dummy_ph,
    dummy_turbidity,
    dummy_contamination
).transact({
    'from': web3.eth.default_account,
    'gas': 2000000 # Increased gas limit, as storing more data costs more. Adjust if needed.
})

print(f"Sending transaction... Transaction hash: {txn.hex()}")

# Wait for the transaction to be mined and get the receipt
receipt = web3.eth.wait_for_transaction_receipt(txn)
print("✅ Dummy data stored on blockchain!")
print("Transaction Receipt:", receipt)
# Out:
# Sending transaction... Transaction hash: b0bc9639f01b1b9d939883cf269960b29ec869821b179d15494387a085560ba2
# ✅ Dummy data stored on blockchain!
# ...

# %%
# Verify if data retrieval works:
total_records = contract.functions.getTotalRecords().call()
print(f"Total Records: {total_records}")

# Retrieve the first stored record (index 0)
# Remember that values like temperature, pH, etc., are scaled and need to be divided
record = contract.functions.getRecord(0).call()
print("First Stored Record (raw):", record)

# Optional: Print more readable format for the first record
if total_records > 0:
    # Unpack the tuple returned by getRecord
    (
        blockTimestamp,
        sensorId,
        temperatureC_scaled,
        humidityPercent,
        co2PPM,
        pm25ugm3_scaled,
        soilMoisturePercent,
        pH_scaled,
        turbidityNTU_scaled,
        contaminationPPM_scaled
    ) = record

    print("\nFirst Stored Record (decoded):")
    print(f"  Timestamp (Unix): {blockTimestamp}") # This is a Unix timestamp
    print(f"  Sensor ID: {sensorId}")
    print(f"  Temperature: {temperatureC_scaled / 10.0}°C") # Divide by 10
    print(f"  Humidity: {humidityPercent}%")
    print(f"  CO2: {co2PPM} ppm")
    print(f"  PM2.5: {pm25ugm3_scaled / 10.0} µg/m³") # Divide by 10
    print(f"  Soil Moisture: {soilMoisturePercent}%")
    print(f"  pH: {pH_scaled / 10.0}") # Divide by 10
    print(f"  Turbidity: {turbidityNTU_scaled / 10.0} NTU") # Divide by 10
    print(f"  Contamination: {contaminationPPM_scaled / 100.0} ppm") # Divide by 100
# Out:
# Total Records: 1
# First Stored Record (raw): [1748188690, 'TEST-SENSOR-001', 255, 60, 800, 123, 45, 70, 51, 75]
#
# First Stored Record (decoded):
#   Timestamp (Unix): 1748188690
#   Sensor ID: TEST-SENSOR-001
#   Temperature: 25.5°C
#   Humidity: 60%
#   CO2: 800 ppm
#   PM2.5: 12.3 µg/m³
#   Soil Moisture: 45%
#   pH: 7.0
#   Turbidity: 5.1 NTU
#   Contamination: 0.75 ppm
